# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv("HousingNew.csv")

# %%
df.head()
# Out:
#    ID    price  lotsize  bedrooms  bathrms  stories  garagepl recroom  \
# 0   1  42000.0     5850         3        1        2         1      no
# 1   2  38500.0     4000         2        1        1         0      no
# 2   3  49500.0     3060         3        1        1         0      no
# 3   4  60500.0     6650         3        1        2         0     yes
# 4   5  61000.0     6360         2        1        1         0      no
#
#   fullbase airco
# 0      yes    no
# 1       no    no
# 2       no    no
# 3       no    no
# 4       no    no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        546 non-null    int64
#  1   price     546 non-null    float64
#  2   lotsize   546 non-null    int64
#  3   bedrooms  546 non-null    int64
#  4   bathrms   546 non-null    int64
#  5   stories   546 non-null    int64
#  6   garagepl  546 non-null    int64
#  7   recroom   546 non-null    object
#  8   fullbase  546 non-null    object
#  9   airco     546 non-null    object
# dtypes: float64(1), int64(6), object(3)
# memory usage: 42.8+ KB

# %%
df.describe()
# Out:
#                ID          price       lotsize    bedrooms     bathrms  \
# count  546.000000     546.000000    546.000000  546.000000  546.000000
# mean   273.500000   68121.597070   5150.265568    2.965201    1.285714
# std    157.760895   26702.670926   2168.158725    0.737388    0.502158
# min      1.000000   25000.000000   1650.000000    1.000000    1.000000
# 25%    137.250000   49125.000000   3600.000000    2.000000    1.000000
# 50%    273.500000   62000.000000   4600.000000    3.000000    1.000000
# 75%    409.750000   82000.000000   6360.000000    3.000000    2.000000
# max    546.000000  190000.000000  16200.000000    6.000000    4.000000
#
#           stories    garagepl
# count  546.000000  546.000000
# mean     1.807692    0.692308
# std      0.868203    0.861307
# min      1.000000    0.000000
# 25%      1.000000    0.000000
# 50%      2.000000    0.000000
# 75%      2.000000    1.000000
# max      4.000000    3.000000

# %%
df.columns
# Out:
# Index(['ID', 'price', 'lotsize', 'bedrooms', 'bathrms', 'stories', 'garagepl',
#        'recroom', 'fullbase', 'airco'],
#       dtype='object')

# %%
#you can do this if data is not large
sns.pairplot(df)

# %%
#check distribution of target column,price of house

# %%
sns.displot(df['price'])

# %%
#find correlation and actual amount

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['ID', 'price', 'lotsize', 'bedrooms', 'bathrms', 'stories', 'garagepl',
#        'recroom', 'fullbase', 'airco'],
#       dtype='object')

# %%
X = df[['ID', 'price', 'lotsize', 'bedrooms', 'bathrms', 'stories', 'garagepl',
       'recroom', 'fullbase', 'airco']]

# %%
y = df['price']

# %%
# !pip install sklearn
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1321 sha256=3a09221be70f4048d1075d53655f2e7cacd823abb2d36820937e18a06060882c
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\22\0b\40\fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
ld = LinearRegression()

# %%
ld.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-0b39982cb5a6> in <module>
# ----> 1 ld.fit(X_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...

# %%
print(ld.predict)
# Out:
# <bound method LinearModel.predict of LinearRegression()>

# %%
X_train.columns
# Out:
# Index(['ID', 'price', 'lotsize', 'bedrooms', 'bathrms', 'stories', 'garagepl',
#        'recroom', 'fullbase', 'airco'],
#       dtype='object')

# %%
ld.predict(y_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-50-9e218ec60fa1> in <module>
# ----> 1 ld.predict(y_test)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     214
#     215     def _decision_function(self, X):
# --> 216         check_is_fitted(self)
#     217
#     218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
# ...
