# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\Hp\\CBD'

# %% [markdown]
# Read csv file

# %%
df=pd.read_csv('C:\\Users\\Hp\\CBD\\winequality-red.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# Get column name by loop

# %%
for data in df.columns:
    print(data)
# Out:
# fixed acidity
# volatile acidity
# citric acid
# residual sugar
# chlorides
# free sulfur dioxide
# total sulfur dioxide
# density
# pH
# sulphates
# alcohol
# quality

# %% [markdown]
# get columns without loop

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
a=df.tail(10)

# %%
a
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# get last column of dataframe

# %%
df.iloc[10:,-1:]
# Out:
#       quality
# 10          5
# 11          5
# 12          5
# 13          5
# 14          5
# ...       ...
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#
# [1589 rows x 1 columns]

# %%
df.iloc[:,-1].tail(10)
# Out:
# 1589    5
# 1590    6
# 1591    6
# 1592    6
# 1593    6
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, dtype: int64

# %% [markdown]
# Print last 10 rows of last column

# %%
for i in range(1,10):
    print(df.iloc[:,-1:].tail(i))
# Out:
#       quality
# 1598        6
#       quality
# 1597        5
# 1598        6
#       quality
# 1596        6
# 1597        5
# 1598        6
#       quality
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#       quality
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#       quality
# 1593        6
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#       quality
# 1592        6
# 1593        6
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#       quality
# 1591        6
# 1592        6
# 1593        6
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#       quality
# 1590        6
# 1591        6
# 1592        6
# 1593        6
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6

# %%
df.plot(kind = 'scatter', x = 'fixed acidity', y = 'quality')
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>
